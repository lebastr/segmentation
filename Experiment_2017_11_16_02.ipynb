# %% [markdown]
# В этом эксперименте производится попытка выучить Unet на 60 эпохах на тестовой выборке без порождения дополнительных примеров с помощью поворотов и масштабирования

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !nvidia-smi
# Out:
# Fri Nov 17 13:08:39 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.90                 Driver Version: 384.90                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    30W / 149W |     16MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import random
import copy

import datetime

from shutil import copyfile
import os
import json

# %%
DESCRIPTION = "Train Unet without any data augmentation on 60 epochs. Experiment_2017_11_16_02"
DATE = str(datetime.datetime.now())

DIR = './experiments/%s' % DATE

os.mkdir(DIR)

json.dump(DESCRIPTION, open(DIR + "/description.txt", "w"))
MODULES = ['dataset', 'unet', 'train_test_loader']

for m in MODULES:
    fname = "%s.py" % m
    copyfile(fname, DIR + '/' + fname)

[s, u, train_test_loader] = map(__import__, MODULES)
# Out:
# Using TensorFlow backend.

# %%
data_set = s.DataSet("./dataset/trainset", [s.ChannelPAN], image_size=(240,240))
ids = data_set.load()

train_ids, test_ids = train_test_loader.load_train_test()

# %%
net = u.UnetModel('classic-unet', data_set, DIR + "/model")

# %%
# %time net.train(u.BatchGenerator, train_ids, epochs=60)
# Out:
# epoch: 0, loss: 0.818140
# epoch: 0, loss: 0.810582
# epoch: 0, loss: 0.800807
# epoch: 0, loss: 0.777146
# epoch: 0, loss: 0.761742
# epoch: 0, loss: 0.751806
# epoch: 0, loss: 0.744595
# epoch: 0, loss: 0.738302
# epoch: 0, loss: 0.740968
# epoch: 0, loss: 0.727327
# epoch: 0, loss: 0.714671
# epoch: 0, loss: 0.700081
# epoch: 0, loss: 0.707693
# epoch: 0, loss: 0.711552
# epoch: 0, loss: 0.685775
# epoch: 0, loss: 0.676319
# epoch: 0, loss: 0.686135
# epoch: 0, loss: 0.655142
# epoch: 0, loss: 0.655692
# epoch: 0, loss: 0.646212
# epoch: 0, loss: 0.646766
# epoch: 0, loss: 0.641449
# epoch: 0, loss: 0.625579
# epoch: 0, loss: 0.649399
# epoch: 0, loss: 0.607457
# epoch: 0, loss: 0.622025
# epoch: 0, loss: 0.601254
# epoch: 0, loss: 0.573389
# epoch: 0, loss: 0.579909
# epoch: 0, loss: 0.627660
# epoch: 0, loss: 0.606612
# epoch: 0, loss: 0.592464
# epoch: 0, loss: 0.570610
# epoch: 0, loss: 0.587929
# epoch: 0, loss: 0.541929
# epoch: 0, loss: 0.570382
# epoch: 0, loss: 0.542653
# ...
